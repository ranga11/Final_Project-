# %%
import matplotlib
import matplotlib.pylab as plt
import matplotlib.finance as mpf
matplotlib.style.use('seaborn')
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 5
from plotly.graph_objs import *
from plotly.offline import init_notebook_mode, iplot, iplot_mpl
init_notebook_mode()
from tqdm import tqdm
import statsmodels.api as sm
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
from statsmodels.tsa.arima_model import ARIMA
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
# C:\Users\HP\Anaconda32\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning:
#
# The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.

# %%
from googlefinance.client import get_price_data, get_prices_data, get_prices_time_data

# %%
from googlefinance.client import get_price_data, get_prices_data, get_prices_time_data
params = [{'q':'AAL'}]
period = "5Y"
# get open, high, low, close, volume data (return pandas dataframe)
df = get_prices_data(params, period)
df.head()
# Out:
#             AAL_Open  AAL_High  AAL_Low  AAL_Close  AAL_Volume
# 2013-12-09     23.85     25.44  23.4501      24.60    43197268
# 2013-12-10     24.50     25.17  24.4100      24.88    18660625
# 2013-12-11     25.48     27.20  25.3700      25.99    38843371
# 2013-12-12     26.20     26.71  25.4500      25.45    19981824
# 2013-12-13     25.75     26.30  25.5201      26.23    12192421

# %%
df = get_prices_data(params, period)
df.reset_index(level=0,inplace=True)
df=df.rename(index=str, columns={"index": "Date"})
df.columns
# Out:
# Index(['Date', 'AAL_Open', 'AAL_High', 'AAL_Low', 'AAL_Close', 'AAL_Volume'], dtype='object')

# %%
Series = df[['Date','AAL_Close']]

# %%
plt.figure(figsize=(15,7))
Series.plot()
plt.show()

# %%
#Time Series Plot
import plotly.plotly as py
import plotly.graph_objs as go
import plotly as ply

ply.plotly.sign_in(username='Ranga_Chari', api_key='L9dHdlgu0wpPRNepbtUF')
data = [go.Scatter(x=df.Date, y=df.AAL_Close)]
py.iplot(data)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~Ranga_Chari/14.embed" height="525px" width="100%"></iframe>

# %%
df['Date'] = pd.to_datetime(df['Date'])
df1= df.set_index('Date')

# %%
series2=df1['AAL_Close']
#series2

# %%
pd.Series.autocorr(df2,lag=7)
# Out:
# 0.92324302532590785

# %%
##### autocorrelation_plot(series)
plt.figure(figsize=(15,7))
plt.show()

# %%
# fit model
model = ARIMA(df2, order=(3,1,0))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:            D.AAL_Close   No. Observations:                 1099
# Model:                 ARIMA(3, 1, 0)   Log Likelihood               -1487.077
# Method:                       css-mle   S.D. of innovations              0.936
# Date:                Mon, 23 Apr 2018   AIC                           2984.154
# Time:                        20:58:55   BIC                           3009.165
# Sample:                    12-10-2013   HQIC                          2993.617
#                          - 04-23-2018
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 0.0201      0.030      0.664      0.507      -0.039       0.080
# ar.L1.D.AAL_Close     0.0613      0.030      2.033      0.042       0.002       0.120
# ar.L2.D.AAL_Close     0.0209      0.030      0.691      0.490      -0.038       0.080
# ar.L3.D.AAL_Close    -0.0140      0.030     -0.464      0.643      -0.073       0.045
#                                     Roots
# =============================================================================
#                  Real           Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -4.0191           -0.0000j            4.0191           -0.5000
# AR.2            2.7551           -3.1903j            4.2152           -0.1366
# AR.3            2.7551           +3.1903j            4.2152            0.1366
# -----------------------------------------------------------------------------

# %%
# plot residual errors
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()
plt.show()
residuals.plot(kind='kde')
plt.show()
print(residuals.describe())
# Out:
#                  0
# count  1099.000000
# mean     -0.000030
# std       0.936724
# min      -4.747355
# 25%      -0.509150
# 50%       0.011112
# 75%       0.555689
# max       3.469952

# %%
#Rolling Forecast ARIMA Model
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
X = df2.values
size = int(len(X) * 0.80)
train = X[0:size]
test = X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error
# predicted=52.301969, expected=52.070000
# predicted=52.074241, expected=52.030000
# predicted=52.055764, expected=51.510000
# predicted=51.516097, expected=51.930000
# predicted=51.965953, expected=50.980000
# predicted=50.973877, expected=51.950000
# predicted=52.000227, expected=51.020000
# predicted=51.034737, expected=48.610000
# predicted=48.476338, expected=47.560000
# predicted=47.454649, expected=47.250000
# predicted=47.292455, expected=46.820000
# predicted=46.846429, expected=47.840000
# predicted=47.910139, expected=47.360000
# predicted=47.384332, expected=47.450000
# predicted=47.447805, expected=47.510000
# predicted=47.527837, expected=46.460000
# predicted=46.439500, expected=46.370000
# predicted=46.349326, expected=45.770000
# predicted=45.772246, expected=45.820000
# predicted=45.844736, expected=45.740000
# predicted=45.757716, expected=45.810000
# predicted=45.839241, expected=47.190000
# predicted=47.286160, expected=47.680000
# predicted=47.769390, expected=47.390000
# predicted=47.381737, expected=47.690000
# predicted=47.690575, expected=48.650000
# predicted=48.747841, expected=48.660000
# predicted=48.713496, expected=48.560000
# predicted=48.553447, expected=48.420000
# predicted=48.420212, expected=49.220000
# predicted=49.296661, expected=49.250000
# predicted=49.300245, expected=50.490000
# predicted=50.573137, expected=49.000000
# predicted=48.962660, expected=49.930000
# predicted=49.943456, expected=49.470000
# predicted=49.510814, expected=49.610000
# predicted=49.639529, expected=50.880000
# predicted=50.952892, expected=51.020000
# predicted=51.105236, expected=51.300000
# predicted=51.313060, expected=50.470000
# predicted=50.438294, expected=50.090000
# predicted=50.076342, expected=50.210000
# predicted=50.242371, expected=51.060000
# predicted=51.157529, expected=51.490000
# predicted=51.556281, expected=51.440000
# predicted=51.450716, expected=51.920000
# predicted=51.948937, expected=52.790000
# predicted=52.882424, expected=52.590000
# predicted=52.627392, expected=52.850000
# predicted=52.859089, expected=52.400000
# predicted=52.406056, expected=52.460000
# predicted=52.484128, expected=52.030000
# predicted=52.036891, expected=52.990000
# predicted=53.062375, expected=52.340000
# predicted=52.363978, expected=52.670000
# predicted=52.679534, expected=52.650000
# predicted=52.679851, expected=52.130000
# predicted=52.141988, expected=52.080000
# predicted=52.074459, expected=53.780000
# predicted=53.907613, expected=56.420000
# predicted=56.656854, expected=58.470000
# predicted=58.669761, expected=57.980000
# predicted=57.953811, expected=58.160000
# predicted=58.118634, expected=58.340000
# predicted=58.400811, expected=58.060000
# predicted=58.105085, expected=58.100000
# predicted=58.111813, expected=58.290000
# predicted=58.338718, expected=54.790000
# predicted=54.619994, expected=53.050000
# predicted=52.848135, expected=53.070000
# predicted=53.118313, expected=52.680000
# predicted=52.769301, expected=52.590000
# predicted=52.587316, expected=54.320000
# predicted=54.458120, expected=53.880000
# predicted=53.937369, expected=52.100000
# predicted=51.965687, expected=49.760000
# predicted=49.553543, expected=51.180000
# predicted=51.297741, expected=51.400000
# predicted=51.547875, expected=48.600000
# predicted=48.425889, expected=48.360000
# predicted=48.285781, expected=50.090000
# predicted=50.267181, expected=50.870000
# predicted=50.982725, expected=51.070000
# predicted=51.081940, expected=51.670000
# predicted=51.716730, expected=51.580000
# predicted=51.599682, expected=51.720000
# predicted=51.742120, expected=52.780000
# predicted=52.876888, expected=52.980000
# predicted=53.031354, expected=53.390000
# predicted=53.428317, expected=55.000000
# predicted=55.134286, expected=54.260000
# predicted=54.253205, expected=54.250000
# predicted=54.241386, expected=53.480000
# predicted=53.457425, expected=53.180000
# predicted=53.181133, expected=53.190000
# predicted=53.222476, expected=53.570000
# predicted=53.630142, expected=54.110000
# predicted=54.178269, expected=54.790000
# predicted=54.863603, expected=56.070000
# predicted=56.183671, expected=56.500000
# predicted=56.562573, expected=56.230000
# predicted=56.221635, expected=55.280000
# predicted=55.221658, expected=55.170000
# predicted=55.176565, expected=55.400000
# predicted=55.458640, expected=54.620000
# predicted=54.604700, expected=55.320000
# predicted=55.381338, expected=54.090000
# predicted=54.055265, expected=52.310000
# predicted=52.190708, expected=51.010000
# predicted=50.926964, expected=51.860000
# predicted=51.962329, expected=50.900000
# predicted=50.898465, expected=50.850000
# predicted=50.850693, expected=51.960000
# predicted=52.071622, expected=49.780000
# predicted=49.681730, expected=51.470000
# predicted=51.548850, expected=52.040000
# predicted=52.135941, expected=52.140000
# predicted=52.185937, expected=50.290000
# predicted=50.182240, expected=49.820000
# predicted=49.780131, expected=47.460000
# predicted=47.342488, expected=45.400000
# predicted=45.249496, expected=46.570000
# predicted=46.674134, expected=45.870000
# predicted=45.908224, expected=46.400000
# predicted=46.461051, expected=45.750000
# predicted=45.736650, expected=47.760000
# predicted=47.884271, expected=46.880000
# predicted=46.898687, expected=46.780000
# predicted=46.748030, expected=46.680000
# Test MSE: 0.913
# R2 of Testing Data= 0.915242541071

# %%
plt.figure(figsize=(15,7))
plt.plot(test)
plt.plot(predictions, color='red')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-148-48347425afb3> in <module>()
#       1 from sklearn.metrics import r2_score
# ----> 2 R2 = r2_score(test,predictions)
#       3 print('R2 of Testing Data=',R2)
#
# ~\Anaconda32\lib\site-packages\sklearn\metrics\regression.py in r2_score(y_true, y_pred, sample_weight, multioutput)
#     528     """
#     529     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 530         y_true, y_pred, multioutput)
#     531
#     532     if sample_weight is not None:
#
# ~\Anaconda32\lib\site-packages\sklearn\metrics\regression.py in _check_reg_targets(y_true, y_pred, multioutput)
#      73
#      74     """
# ---> 75     check_consistent_length(y_true, y_pred)
#      76     y_true = check_array(y_true, ensure_2d=False)
#      77     y_pred = check_array(y_pred, ensure_2d=False)
#
# ~\Anaconda32\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     202     if len(uniques) > 1:
#     203         raise ValueError("Found input variables with inconsistent numbers of"
# --> 204                          " samples: %r" % [int(l) for l in lengths])
#     205
#     206
#
# ValueError: Found input variables with inconsistent numbers of samples: [220, 222]

# %% [markdown]
# ### Linear Regression

# %%
X = df.iloc[:,[1,2,3,5]].values
Y = df.iloc[:,4].values

# %%
## fitting multiple linear regression to the training set
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
regressor = LinearRegression()
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=np.random)
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
Y_predictions = regressor.predict(X_test)
#print(regressor.intercept_)
#print(regressor.coef_)
Y_predictions

# %%
import math
test_pred =regressor.predict(X_test)
MSE = mean_squared_error(Y_test,test_pred)
#RMSE = math.sqrt(MSE)
print('MSE of Testing Data=',MSE)
## R-square score of this model
R2 = r2_score(Y_test,test_pred)
print('R2 of Testing Data=',R2)
# Out:
# MSE of Testing Data= 0.151836990339
# R2 of Testing Data= 0.996558419834

# %%
# Predicting the test set results
train_pred =regressor.predict(X_train)
## Mean squared error
MSE = mean_squared_error(Y_train,train_pred)
#RMSE = math.sqrt(MSE)
print('RMSE of Training Data =',MSE)
## R-square score of this model
R2 = r2_score(Y_train,train_pred)
print('R2 of Training Data =',R2)
# Out:
# RMSE of Training Data = 0.13363422689
# R2 of Training Data = 0.997056318528

# %%
plt.figure(figsize=(15,7))
plt.plot(Y_test)
plt.plot(Y_predictions, color='red')
plt.show()
